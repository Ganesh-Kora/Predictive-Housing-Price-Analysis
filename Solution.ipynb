# %% [markdown]
# # Home Price Prediction

# %% [markdown]
# # Project Description:
#
# In this particular project, we are using a dataset that contains information like, Address, Rooms, Type, Price, Seller etc and using that to predict the price of a given house.
#
#
# However, before you go ahead and make a prediction, it is advised that you first pre-process the data, since it may contain some irregularities and noise. In addition, try various tricks and techniques in order to gain the best accuracy in your predictions.

# %% [markdown]
# # Column details(Meta description)

# %% [raw]
# Suburb: Suburb
# Address: Address
# Rooms: Number of rooms
# Price: Price in Australian dollars
# Method:
# S - property sold;
# SP - property sold prior;
# PI - property passed in;
# PN - sold prior not disclosed;
# SN - sold not disclosed;
# NB - no bid;
# VB - vendor bid;
# W - withdrawn prior to auction;
# SA - sold after auction;
# SS - sold after auction price not disclosed.
# N/A - price or highest bid not available.
#
# Type:
# br - bedroom(s);
# h - house, cottage, villa, semi, terrace;
# u - unit, duplex;
# t - townhouse;
# dev site - development site;
# o res - other residential.
# SellerG: Real Estate Agent
# Date: Date sold
# Distance: Distance from CBD in Kilometres
# Regionname: General Region (West, North West, North, North east …etc)
# Propertycount: Number of properties that exist in the suburb.
# Bedroom2 : Scraped # of Bedrooms (from different source)
# Bathroom: Number of Bathrooms
# Car: Number of cars spots
# Landsize: Land Size in Metres
# BuildingArea: Building Size in Metres
# YearBuilt: Year the house was built
# CouncilArea: Governing council for the area
# Lattitude: Self explanatory
# Longtitude: Self explanatory

# %% [markdown]
# # Part-1: data Exploration and Pre-processing

# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score, mean_absolute_error
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,precision_score,recall_score,f1_score,classification_report,accuracy_score, roc_curve,roc_auc_score
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split,KFold,cross_val_score

# %% [markdown]
# # 1) Load the given dataset

# %%
data=pd.read_csv(r"E:\GANESH\ML\Home Price Prediction & Analysis\EXCEL -Home Price Prediction & Analysis.csv")

# %%
data
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis  03/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %% [markdown]
# # 2) Print all the column names

# %%
data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %% [markdown]
# # 3) Describe the data

# %%
data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# ...

# %%
# We Can Also Check The Information Of The Data Like....

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  BuildingArea   13742 non-null  float64
#  15  YearBuilt      15551 non-null  float64
#  16  CouncilArea    34854 non-null  object
# ...

# %% [markdown]
# # 4) Drop address, date, postcode, YearBuilt, lattitude, longtitude columns

# %%
#Columns ko actual data se drop karne ke liye hum following statement use karte hain...

#data.drop(["Address", "Date", "Postcode", "YearBuilt", "Lattitude", "Longtitude"], axis = 1)

#Columns ko actual data se delete karne ke liye hum ye karte hain...

data.drop(["Address", "Date", "Postcode", "YearBuilt", "Lattitude", "Longtitude"], axis = 1, inplace = True)

# 2nd way...

# data = data.drop(["Address", "Date", "Postcode", "YearBuilt", "Lattitude", "Longtitude"], axis = 1)

# %%
data
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# ...

# %%
# We Can See All The Provided Columns Will Be Successfully Removed From The Data...

# %% [markdown]
# # 5) Find the count of null value in each column

# %%
data.isnull()
# Out:
#        Suburb  Rooms   Type  Price  Method  SellerG  Distance  Bedroom2  \
# 0       False  False  False   True   False    False     False     False
# 1       False  False  False  False   False    False     False     False
# 2       False  False  False  False   False    False     False     False
# 3       False  False  False   True   False    False     False     False
# 4       False  False  False  False   False    False     False     False
# ...       ...    ...    ...    ...     ...      ...       ...       ...
# 34852   False  False  False  False   False    False     False     False
# 34853   False  False  False  False   False    False     False     False
# 34854   False  False  False  False   False    False     False     False
# 34855   False  False  False  False   False    False     False      True
# 34856   False  False  False  False   False    False     False     False
#
#        Bathroom    Car  Landsize  BuildingArea  CouncilArea  Regionname  \
# ...

# %%
# Upar Humne Boolean Values Wala Table Dekha Jo Null Data Availability Ko Show Kar Raha Hai Taaki Hum Unhe Count Kar Sakein...

data.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        3
# dtype: int64

# %% [markdown]
# # 6) Fill the null value of property count, distance, Bedroom2, Bathroom, Car with 0

# %%
# It Is Necessary To Pass The Columns Within The List Of List When We Have Multiple Column Names....

data[["Distance", "Bedroom2", "Bathroom", "Car"]] = data[["Distance", "Bedroom2", "Bathroom", "Car"]].fillna(0, axis = 1)

# OR

# data[["Distance", "bedroom2", "Bathroom", "Car"]].fillna(0, axis = 1, inplace = True)

# %%
# Single Column Missing Value Filling...

data["Propertycount"] = data["Propertycount"].fillna(0)

# %%
data
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# ...

# %%
# Chekc The Null Values After Filling It..

data.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             0
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        0
# dtype: int64

# %%
# Work Is Done And Score Is Changed...

# %% [markdown]
# # 7) Fill Null value of land size and bidding area columns with Mean

# %%
# We Need To Calculate The Mean's Differently Like Following...

data["Landsize"] = data["Landsize"].fillna(data["Landsize"].mean())

# %%
print(data["Landsize"].mean())
# Out:
# 593.598993361392

# %%
# Then Filling The Second Column...

data["BuildingArea"] = data["BuildingArea"].fillna(data["BuildingArea"].mean())

# %%
print(data["BuildingArea"].mean())
# Out:
# 160.25640035657108

# %%
# Sirf Saari Rows Ko Dekhne Ke Liye Use Karein...

#    pd.set_option("display.max_rows", 50000)

# %%
data
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car    Landsize  BuildingArea  \
# ...

# %%
# Data Ko Dekhne Ke Baad, Hume Options Ko Reset Karna Padega Jaisa Ki Neeche Bataya Hai...

# pd.reset_option("display.max_rows", None)

# %%
data
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car    Landsize  BuildingArea  \
# ...

# %% [markdown]
# # 8) Find the unique value in method column

# %%
data.columns
# Out:
# Index(['Suburb', 'Rooms', 'Type', 'Price', 'Method', 'SellerG', 'Distance',
#        'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea',
#        'CouncilArea', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
# Check All Unique Values For "Method" Columns...

data["Method"].unique()
# Out:
# array(['SS', 'S', 'VB', 'SP', 'PI', 'SN', 'W', 'PN', 'SA'], dtype=object)

# %% [markdown]
# # 9) Create a dummy data for categorical data

# %% [raw]
# dummy data for categorical variables by generating sample data with different categories. This helps in testing and demonstrating algorithms on categorical datasets. For example, you can create a DataFrame with columns like 'Category' and 'Type' containing sample categorical values.

# %%
data = pd.get_dummies(data, drop_first = True)

# %%
data
# Out:
#        Rooms      Price  Distance  Bedroom2  Bathroom  Car    Landsize  \
# 0          2        NaN       2.5       2.0       1.0  1.0  126.000000
# 1          2  1480000.0       2.5       2.0       1.0  1.0  202.000000
# 2          2  1035000.0       2.5       2.0       1.0  0.0  156.000000
# 3          3        NaN       2.5       3.0       2.0  1.0    0.000000
# 4          3  1465000.0       2.5       3.0       2.0  0.0  134.000000
# ...      ...        ...       ...       ...       ...  ...         ...
# 34852      4  1480000.0       6.3       4.0       1.0  3.0  593.000000
# 34853      2   888000.0       6.3       2.0       2.0  1.0   98.000000
# 34854      2   705000.0       6.3       2.0       1.0  2.0  220.000000
# 34855      3  1140000.0       6.3       0.0       0.0  0.0  593.598993
# 34856      2  1020000.0       6.3       2.0       1.0  0.0  250.000000
#
#        BuildingArea  Propertycount  Suburb_Aberfeldie  ...  \
# ...

# %%
data.head()
# Out:
#    Rooms      Price  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0      2        NaN       2.5       2.0       1.0  1.0     126.0
# 1      2  1480000.0       2.5       2.0       1.0  1.0     202.0
# 2      2  1035000.0       2.5       2.0       1.0  0.0     156.0
# 3      3        NaN       2.5       3.0       2.0  1.0       0.0
# 4      3  1465000.0       2.5       3.0       2.0  0.0     134.0
#
#    BuildingArea  Propertycount  Suburb_Aberfeldie  ...  \
# 0      160.2564         4019.0              False  ...
# 1      160.2564         4019.0              False  ...
# 2       79.0000         4019.0              False  ...
# 3      160.2564         4019.0              False  ...
# 4      150.0000         4019.0              False  ...
#
#    CouncilArea_Wyndham City Council  CouncilArea_Yarra City Council  \
# 0                             False                            True
# 1                             False                            True
# ...

# %%
data.shape
# Out:
# (34857, 795)

# %%
data.columns
# Out:
# Index(['Rooms', 'Price', 'Distance', 'Bedroom2', 'Bathroom', 'Car', 'Landsize',
#        'BuildingArea', 'Propertycount', 'Suburb_Aberfeldie',
#        ...
#        'CouncilArea_Wyndham City Council', 'CouncilArea_Yarra City Council',
#        'CouncilArea_Yarra Ranges Shire Council', 'Regionname_Eastern Victoria',
#        'Regionname_Northern Metropolitan', 'Regionname_Northern Victoria',
#        'Regionname_South-Eastern Metropolitan',
#        'Regionname_Southern Metropolitan', 'Regionname_Western Metropolitan',
#        'Regionname_Western Victoria'],
#       dtype='object', length=795)

# %%
# Yahan Pe Cleaning Part Complete Ho Gaya...

# %% [markdown]
# # Part-2: Working with Model

# %% [markdown]
# # 1) Create the target data and feature data where target data is price

# %%
x=data.drop("Price", axis = 1)

# %%
y = data["Price"]

# %%
# Both Are Created Successfully...

# %% [markdown]
# # 2) Create a linear regression model for Target and feature data

# %% [raw]
# Linear regression is a simple and widely used statistical method for predicting a continuous target variable based on one or more input features. It works by fitting a linear equation (a straight line) to the observed data, minimizing the sum of squared differences between the observed and predicted values. This technique helps in understanding relationships between variables and making predictions.

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
# Model Ko Fit Karne Ke Liye Hume 'train_test_split' Function Use Karna Padega...

# %%
x_train ,x_test , y_train , y_test = train_test_split(x,y, train_size = 0.75, random_state = 10)

# %% [markdown]
# # 3) Check if the model is overfitting or underfitting or it is accurate

# %% [raw]
# if the model is overfitting, underfitting, or accurate, compare its performance on training and testing datasets. If the model performs well on training data but poorly on testing data, it is overfitting. If it performs poorly on both, it is underfitting. An accurate model will have good performance on both datasets.

# %%
     # model.fit(x_train, y_train)


#      We Can't Fit The Model Because Some Row Values Are Still Contains 'NaN' Values...

# %%
# Uske Liye Hum Yeh Kar Sakte Hain...
# 'isna()' Method Object Datatype Ke Data Ke Liye Hai Jo 'NaN(NA)' Values Ko Dhoondta Hai...

data.isna().any(axis = 1)

# For Sum Those Data

data.isna().any(axis = 1).sum()
# Out:
# 7610

# %%
# Aise Data Ke Liye Hume Un Sabhi Ko Remove Karna Hoga...

#data.dropna() 

# Yeh Temporary Changes Karta Hai... Permanent Banane Ke Liye Hum Ye Kar Sakte Hain....


data.dropna(inplace = True)

# %%
# Then We Can Re-Check The Sum...

data.isna().any(axis = 1).sum()
# Out:
# 0

# %%
# After That We Can Fit The Model...

# %%
x=data.drop("Price", axis = 1)

# %%
y = data["Price"]

# %%
x_train ,x_test , y_train , y_test = train_test_split(x,y, train_size = 0.90, random_state = 26)

# %%
x_train ,x_test , y_train , y_test = train_test_split(x,y, train_size = 0.60, random_state = 20)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.6843293325757609

# %%
model.score(x_test,y_test)
# Out:
# 0.6607430794477525

# %%
# Sample Changes Ke Baad Bhi Score Waisa Hi Rahega Jaise Pehle Tha....

# %% [markdown]
# # 4) If the model is overfitting then apply ridge and lasso regression algorithms

# %% [raw]
# the model is overfitting, apply Ridge and Lasso regression algorithms to address the issue. Ridge regression adds a penalty term to the loss function proportional to the squared magnitude of coefficients, helping in reducing overfitting. Lasso regression, on the other hand, adds a penalty term proportional to the absolute value of coefficients, which not only reduces overfitting but also performs feature selection by driving some coefficients to zero.

# %% [markdown]
# # Lasso (Least Absolute Shrinkage and Selection Operator)

# %% [raw]
# Lasso (Least Absolute Shrinkage and Selection Operator) regression is a type of linear regression that includes a penalty term proportional to the absolute value of the coefficients. This penalty term helps to reduce overfitting by constraining the magnitude of the coefficients, and it also performs feature selection by driving some coefficients to zero. This makes Lasso regression particularly useful when dealing with datasets that have a large number of features.

# %%
from sklearn.linear_model import Lasso, Ridge

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.80, random_state = 42)

# %%
# Model Ka Score Better Banane Ke Liye Yahan Changes Kar Do...

model1 = Lasso(alpha = 20)

# %%
model1.fit(x_train,y_train)
# Out:
# Lasso(alpha=20)

# %%
model1.score(x_train,y_train)
# Out:
# 0.683076077257489

# %%
model1.score(x_test, y_test)
# Out:
# 0.6538169691879245

# %%
# Kuch Changes Ke Baad Bhi Score Apni Peak Pe Rehta Hai...

# %%
# Lasso (Least Absolute Shrinkage and Selection Operator) aur Ridge Regression 
#dono regularization techniques hain jo machine learning models mein overfitting ko rokne ke liye use hoti hain.

# %% [markdown]
# # Ridge regression

# %% [raw]
# Ridge regression is a type of linear regression that includes a penalty term proportional to the squared magnitude of the coefficients. This penalty term helps to reduce overfitting by shrinking the coefficients, thereby improving the model's generalization to new data. Unlike Lasso regression, Ridge regression does not perform feature selection but helps in situations where multicollinearity is present in the data.

# %%
model2=Ridge(alpha=15, max_iter=40)

# %%
model2.fit(x_train,y_train)
# Out:
# Ridge(alpha=15, max_iter=40)

# %%
model2.score(x_train,y_train)
# Out:
# 0.6784698741997996

# %%
model2.score(x_test,y_test)
# Out:
# 0.649462286831882

# %% [markdown]
# # NOTE:- Maximum Iteration Dono Lasso aur Ridge Pe Kaam Karti Hai Jo Iteration Ka Time Define Karti Hai Jab Model Ko Stop Kiya Jata Hai...

# %% [markdown]
# # 5) Extract slope and intercept value from the model

# %% [raw]
# extract the slope (coefficient) from a linear regression model, you can access the model's coefficient attribute after fitting the model to the data. In the case of scikit-learn's LinearRegression class, you can use the .coef_ attribute.
#
# extract the intercept value from a linear regression model, you can access the model's intercept attribute after fitting the model to the data. In the case of scikit-learn's LinearRegression class, you can use the .intercept_ attribute.
#
# extract the slope (coefficient) and intercept value from a linear regression model, you can access the model's coef_ and intercept_ attributes after fitting the model to the data

# %%
# Extarct The Slope Value From Model...

model.coef_
# Out:
# array([ 2.65550000e+05, -4.76763134e+04, -8.60548019e+04,  1.31573325e+05,
#         4.29007016e+04,  8.90262411e+00,  2.69854940e+01,  4.56524328e+00,
#         2.61320403e+05, -3.59992993e+04, -3.03665374e+04,  1.98419347e+05,
#         1.29929320e+05,  2.56709278e+05,  1.34250338e+05, -1.38351521e+05,
#        -1.53948089e+05, -5.35282011e+04,  7.23134001e+04, -1.09100707e+05,
#        -3.86642454e+04, -4.47829056e+04, -4.08710152e+04, -2.56507508e+05,
#        -4.62432578e+04, -2.57269861e+05, -9.22555046e-08,  1.64488232e+05,
#        -9.84701159e+04,  1.77441533e+05, -1.57570590e+04,  8.57929009e+04,
#         2.47283129e+04,  2.02027523e+05, -6.48680725e-07,  1.62334718e+05,
#         2.02271622e-07, -3.42463821e+05,  9.89718989e+04, -4.24188761e+04,
#        -7.79196830e+04,  3.42439160e+05,  1.55797992e+05, -1.34750852e+05,
#        -1.56650982e+05,  1.64255616e+05,  1.14755551e+05,  2.99940572e+05,
# ...

# %%
# The Intercept Value From The Model....

model.intercept_
# Out:
# 655453.0025567871

# %% [markdown]
# # 6) Display Mean Squared Error

# %% [raw]
# Mean Squared Error (MSE) measures the average squared difference between the actual and predicted values. It's calculated by taking the mean of the squared differences between each predicted and actual value. MSE is used to evaluate the performance of regression models, where a lower MSE indicates better accuracy of the model.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mean_squared_error(y, model.predict(x))
# Out:
# 133723245038.50952

# %% [markdown]
# # 7) Display Mean Absolute Error

# %% [raw]
# Mean Absolute Error (MAE) measures the average absolute difference between the actual and predicted values. It's calculated by taking the mean of the absolute differences between each predicted and actual value. MAE is used to evaluate the performance of regression models, where a lower MAE indicates better accuracy.

# %%
mean_absolute_error(y, model.predict(x))
# Out:
# 231693.43457466876

# %% [markdown]
# # 8) Display Root mean Squared error

# %% [raw]
# Root Mean Squared Error (RMSE) measures the average magnitude of the error between the predicted and actual values. It is the square root of the Mean Squared Error (MSE), which gives it the same unit as the target variable. RMSE is used to evaluate regression models, where a lower RMSE indicates better accuracy.

# %%
mean_squared_error(y, model.predict(x)) ** (1 / 2)
# Out:
# 365681.8904984352

# %% [markdown]
# # 9) Display R2 score

# %% [raw]
# The R2 score, also known as the coefficient of determination, measures how well the regression model's predictions match the actual data. It ranges from 0 to 1, where 0 indicates no explanatory power and 1 indicatesperfect prediction. An R2 score closer to 1 means the model explains a large proportion of the variance in the target variable.

# %%
r2_score(y, model.predict(x))
# Out:
# 0.6750069812432131
